# %% [markdown]
# # Creating a DataFrame of URLs and their corresponding Reference Strings

# %%
import os
import pandas as pd
from tqdm import tqdm

# %%
ArticleFile=r'C:\Users\Saranga\Desktop\Devopedia\Work\Devopedia\devopediaArticles.v2525.json'

# %%
ARTICLES = pd.read_json(ArticleFile, orient='index')

# %%
ARTICLES
# Out:
#                              title                          alias  version  \
# 10                            MQTT                           mqtt       14
# 11                          HTTP/2                         http-2        7
# 12          Tensor Processing Unit         tensor-processing-unit        8
# 13                           Li-Fi                          li-fi        6
# 14       Race Condition (Software)        race-condition-software       10
# ..                             ...                            ...      ...
# 328  5G Service-Based Architecture  5g-service-based-architecture        5
# 329          5G Quality of Service          5g-quality-of-service        3
# 331             Scratch (Language)               scratch-language        2
# 332                      Dead Code                      dead-code        4
# 333      Grammar and Spell Checker      grammar-and-spell-checker       12
#
#                                              introtext  \
# ...

# %%
ARTICLES=ARTICLES.drop(['alias','version'],axis=1)

# %%
#copied from provided Github repo's Devopedia-Article-Reader.ipynb file

secs = ARTICLES['secs'].apply(pd.Series)
ARTICLES = pd.concat([ARTICLES, secs], axis=1)
articles = ARTICLES[~ARTICLES.References.isna()]

# %%
articles
# Out:
#                              title  \
# 10                            MQTT
# 11                          HTTP/2
# 12          Tensor Processing Unit
# 13                           Li-Fi
# 14       Race Condition (Software)
# ..                             ...
# 328  5G Service-Based Architecture
# 329          5G Quality of Service
# 331             Scratch (Language)
# 332                      Dead Code
# 333      Grammar and Spell Checker
#
#                                              introtext  \
# 10   Summary\r\n-------\r\n\r\n![image](1873.159524...
# 11   Summary\r\n-------\r\n\r\nHTTP/2 is an alterna...
# 12   Summary\r\n-------\r\n\r\n![image](5335.153133...
# 13   Summary\r\n-------\r\n\r\nLi-Fi, or Light Fide...
# 14   Summary\r\n-------\r\n\r\nRace condition in so...
# ..                                                 ...
# 328  Summary\r\n-------\r\n\r\n![image](8450.161659...
# 329  Summary\r\n-------\r\n\r\n![image](1778.161788...
# ...

# %%
dicto={'url':[],'text':[],'citeas':[]}

# %%
for item in articles.References:
    for i in tqdm(item):
        try:
            dicto['url'].append(i['url'])
            dicto['citeas'].append(i['citeas'])
            dicto['text'].append(i['text'])
        except:
            continue
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████████████████| 49/49 [00:00<?, ?it/s]

# %%
#Verifying wheteher the Columns have the same number of rows

print(len(dicto['url']))
print(len(dicto['text']))
print(len(dicto['citeas']))
# Out:
# 8122
# 8122
# 8122

# %%
df=pd.DataFrame.from_dict(dicto)

# %%
df.to_csv('URL_RefStrings.csv',index=False)

# %%
df
# Out:
#                                                     url  \
# 0     http://docs.oasis-open.org/mqtt/mqtt/v3.1.1/os...
# 1     http://docs.oasis-open.org/mqtt/mqtt/v5.0/mqtt...
# 2     https://www.facebook.com/notes/facebook-engine...
# 3     https://github.com/mqtt/mqtt.github.io/wiki/so...
# 4                                   http://mqtt.org/faq
# ...                                                 ...
# 8117      https://www.aclweb.org/anthology/N18-1055.pdf
# 8118      https://www.aclweb.org/anthology/D19-1510.pdf
# 8119      https://www.aclweb.org/anthology/P07-2045.pdf
# 8120      https://www.aclweb.org/anthology/W09-0424.pdf
# 8121      https://www.aclweb.org/anthology/P10-4002.pdf
#
#                                                    text  \
# 0     Banks, Andrew and Rahul Gupta, eds. 2014. "MQT...
# 1     Banks, Andrew, Ed Briggs, Ken Borgendale, and ...
# 2     Zhang, Lucy. 2011. "Building Facebook Messenge...
# 3     MQTT GitHub. 2014. "Software mqtt/mqtt.github....
# ...
